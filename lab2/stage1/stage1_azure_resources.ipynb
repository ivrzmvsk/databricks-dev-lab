# %% [markdown]
# # Stage 1 — Azure Resources
# ### Storage account overview
# ![storage_account_overview.png](./storage_account_overview.png "storage_account_overview.png")

# %% [markdown]
# ### Key vault overview
# ![Key Vault overview](./key-vault-overview.png)

# %% [markdown]
# ### Workspace overview
# ![Databricks workspace overview](./databricks-workspace-overview.png)
